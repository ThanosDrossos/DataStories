# %% [markdown]
# # Baroque Ceiling Painters - Career Analysis
#
# This notebook analyzes individual painter careers using the DuckDB database.
#
# ## Features
# - **Painter CV**: Timeline of works, locations, and subjects
# - **Geographic Footprint**: Where painters worked across German states
# - **Thematic Analysis**: Common subjects and iconographic themes
# - **Career Timeline**: Chronological view of commissions

# %%
# =============================================================================
# Setup & Connect to Database
# =============================================================================
import duckdb
import polars as pl
import altair as alt
from pathlib import Path
from IPython.display import display as ipython_display, HTML, Markdown

# Configuration
DUCKDB_PATH = Path(r"c:/Users/thano/Documents/_Studium/KIT/DataStories/DataStories/baroque.duckdb") #change

# Enable Altair for larger datasets
alt.data_transformers.disable_max_rows()

# Connect to database
if DUCKDB_PATH.exists():
    con = duckdb.connect(str(DUCKDB_PATH), read_only=True)
    print(f"✅ Connected to: {DUCKDB_PATH.name}")
    
    # Quick stats
    n_paintings = con.execute("SELECT COUNT(*) FROM paintings").fetchone()[0]
    n_painters = con.execute("SELECT COUNT(DISTINCT person_id) FROM painting_persons WHERE role = 'PAINTER'").fetchone()[0]
    print(f"📊 Database contains {n_paintings} paintings by {n_painters} unique painters")
else:
    print(f"❌ Database not found: {DUCKDB_PATH}")
    print("   Run DataStory_Baroque_DuckDB.ipynb first to create the database.")
# Out:
# ✅ Connected to: baroque.duckdb
# 📊 Database contains 4594 paintings by 332 unique painters

# %%
# =============================================================================
# List All Painters with Statistics
# =============================================================================

print("🎨 BAROQUE CEILING PAINTERS OVERVIEW")
print("=" * 70)

painters_overview = con.execute("""
    SELECT 
        pp.person_name,
        pp.person_id,
        COUNT(DISTINCT pp.nfdi_uri) as painting_count,
        COUNT(DISTINCT p.building_id) as building_count,
        COUNT(DISTINCT p.location_state) as states_count,
        MIN(p.year_start) as career_start,
        MAX(p.year_end) as career_end,
        CAST(MAX(p.year_end) - MIN(p.year_start) AS INTEGER) as career_span
    FROM painting_persons pp
    JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
    WHERE pp.role = 'PAINTER'
    GROUP BY pp.person_name, pp.person_id
    ORDER BY painting_count DESC, career_span DESC
""").pl()

print(f"\n📋 Found {len(painters_overview)} painters in database:\n")
print(painters_overview)

# Store painter list for selection
PAINTER_LIST = painters_overview['person_name'].to_list()
# Out:
# 🎨 BAROQUE CEILING PAINTERS OVERVIEW
# ======================================================================
#
# 📋 Found 332 painters in database:
#
# shape: (332, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ person_nam ┆ person_id  ┆ painting_c ┆ building_ ┆ states_co ┆ career_st ┆ career_en ┆ career_sp │
# │ e          ┆ ---        ┆ ount       ┆ count     ┆ unt       ┆ art       ┆ d         ┆ an        │
# │ ---        ┆ str        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆            ┆ i64        ┆ i64       ┆ i64       ┆ i32       ┆ i32       ┆ i32       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ Harms,     ┆ 5b74e880-6 ┆ 119        ┆ 7         ┆ 4         ┆ 1569      ┆ 1780      ┆ 211       │
# │ Johann     ┆ e0d-11ea-a ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Oswald     ┆ 2e8-4df471 ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Lammers,   ┆ c4edb090-f ┆ 82         ┆ 4         ┆ 1         ┆ 1670      ┆ 1750      ┆ 80        │
# │ Seivert    ┆ 559-4970-b ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ 9fb-aba18d ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Castelli,  ┆ 33c17f6b-7 ┆ 70         ┆ 8         ┆ 3         ┆ 1683      ┆ 1770      ┆ 87        │
# │ Carlo      ┆ 2d7-42a7-9 ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Ludovico   ┆ b53-d8ee5e ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Asam,      ┆ 9b20d32c-5 ┆ 63         ┆ 7         ┆ 2         ┆ 1670      ┆ 1948      ┆ 278       │
# │ Cosmas     ┆ 30d-4f46-a ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Damian     ┆ 1b4-52d1bc ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Ritter,    ┆ 6416abf0-5 ┆ 58         ┆ 6         ┆ 1         ┆ 1580      ┆ 1780      ┆ 200       │
# │ Johann     ┆ fd6-45ac-9 ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Heinrich   ┆ f80-ab56a5 ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …         ┆ …         ┆ …         │
# │ Onghers,   ┆ 30ff7926-5 ┆ 1          ┆ 1         ┆ 1         ┆ null      ┆ null      ┆ null      │
# │ Jan        ┆ 06f-4110-b ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ 2e7-5d03a5 ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Martin-Amo ┆ c0dc48ed-1 ┆ 1          ┆ 1         ┆ 1         ┆ null      ┆ null      ┆ null      │
# │ rbach,     ┆ 73f-4d5d-9 ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Oskar      ┆ 42f-74e5a9 ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Scheitler, ┆ 051db01a-6 ┆ 1          ┆ 1         ┆ 1         ┆ null      ┆ null      ┆ null      │
# │ Anton      ┆ deb-4a77-9 ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ 395-6cb232 ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Probst,    ┆ 33d1a336-2 ┆ 1          ┆ 1         ┆ 1         ┆ 1781      ┆ null      ┆ null      │
# │ Johann     ┆ 007-47fc-b ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Michael    ┆ 56e-ae292f ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# │ Reiser,    ┆ 5897d810-9 ┆ 1          ┆ 1         ┆ 1         ┆ null      ┆ null      ┆ null      │
# │ Ambros     ┆ 506-49c2-9 ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ 7ea-15a9b2 ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ …          ┆            ┆           ┆           ┆           ┆           ┆           │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %%
# =============================================================================
# Painter CV Function
# =============================================================================

def generate_painter_cv(painter_name: str):
    """
    Generate a comprehensive CV for a baroque ceiling painter.
    
    Args:
        painter_name: Name of the painter (must match database)
    """
    
    # Get basic info
    basic_info = con.execute("""
        SELECT 
            pp.person_name,
            per.person_type,
            COUNT(DISTINCT pp.nfdi_uri) as total_works,
            COUNT(DISTINCT p.building_id) as buildings,
            COUNT(DISTINCT p.location_state) as states,
            MIN(p.year_start) as earliest_work,
            MAX(p.year_end) as latest_work
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        LEFT JOIN persons per ON pp.person_id = per.person_id
        WHERE pp.role = 'PAINTER' AND pp.person_name = ?
        GROUP BY pp.person_name, per.person_type
    """, [painter_name]).fetchone()
    
    if not basic_info:
        print(f"❌ Painter '{painter_name}' not found in database.")
        print(f"\n💡 Available painters: {', '.join(PAINTER_LIST[:10])}...")
        return
    
    name, person_type, total_works, buildings, states, earliest, latest = basic_info
    
    # Header
    print("\n" + "=" * 70)
    print(f"🎨 PAINTER CV: {name}")
    print("=" * 70)
    
    # Basic Stats
    print(f"\n📋 OVERVIEW")
    print(f"   Type: {person_type or 'Individual'}")
    print(f"   Total documented works: {total_works}")
    print(f"   Buildings worked in: {buildings}")
    print(f"   German states covered: {states}")
    if earliest and latest:
        print(f"   Active period: {earliest} - {latest} ({latest - earliest} years)")
    
    # Works Timeline
    print(f"\n📅 WORKS TIMELINE")
    print("-" * 70)
    
    works = con.execute("""
        SELECT 
            p.label,
            p.year_start,
            p.year_end,
            p.year_is_approximate,
            p.building_name,
            p.building_function,
            p.room_name,
            p.location_state,
            p.nfdi_uri,
            p.imageUrl
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        WHERE pp.role = 'PAINTER' AND pp.person_name = ?
        ORDER BY p.year_start NULLS LAST, p.building_name
    """, [painter_name]).pl()
    
    for i, row in enumerate(works.iter_rows(named=True), 1):
        year_str = ""
        if row['year_start']:
            approx = "~" if row['year_is_approximate'] else ""
            if row['year_end'] and row['year_end'] != row['year_start']:
                year_str = f"{approx}{row['year_start']}-{row['year_end']}"
            else:
                year_str = f"{approx}{row['year_start']}"
        else:
            year_str = "(undated)"
        
        building = row['building_name'] or "Unknown building"
        room = f" → {row['room_name']}" if row['room_name'] else ""
        state = f" [{row['location_state']}]" if row['location_state'] else ""
        func = f" ({row['building_function']})" if row['building_function'] else ""
        
        print(f"   {i:2}. [{year_str:>12}] {building[:40]}{func}")
        if room:
            print(f"                          Room: {row['room_name'][:50]}")
        print(f"                          State: {row['location_state'] or 'Unknown'}")
    
    # Geographic Distribution
    print(f"\n🗺️ GEOGRAPHIC FOOTPRINT")
    print("-" * 70)
    
    geo = con.execute("""
        SELECT 
            p.location_state,
            COUNT(*) as works,
            COUNT(DISTINCT p.building_id) as buildings
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        WHERE pp.role = 'PAINTER' AND pp.person_name = ?
          AND p.location_state IS NOT NULL
        GROUP BY p.location_state
        ORDER BY works DESC
    """, [painter_name]).pl()
    
    for row in geo.iter_rows(named=True):
        print(f"   • {row['location_state']}: {row['works']} work(s) in {row['buildings']} building(s)")
    
    # Building Types
    print(f"\n🏛️ BUILDING TYPES")
    print("-" * 70)
    
    building_types = con.execute("""
        SELECT 
            p.building_function,
            COUNT(*) as works
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        WHERE pp.role = 'PAINTER' AND pp.person_name = ?
          AND p.building_function IS NOT NULL
        GROUP BY p.building_function
        ORDER BY works DESC
    """, [painter_name]).pl()
    
    for row in building_types.iter_rows(named=True):
        print(f"   • {row['building_function']}: {row['works']} work(s)")
    
    # Subjects/Themes
    print(f"\n📚 ICONOGRAPHIC THEMES")
    print("-" * 70)
    
    subjects = con.execute("""
        SELECT 
            s.subject_label,
            s.subject_source,
            COUNT(*) as occurrences
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        JOIN painting_subjects ps ON p.nfdi_uri = ps.nfdi_uri
        JOIN subjects s ON ps.subject_uri = s.subject_uri
        WHERE pp.role = 'PAINTER' AND pp.person_name = ?
          AND s.subject_label IS NOT NULL
        GROUP BY s.subject_label, s.subject_source
        ORDER BY occurrences DESC
        LIMIT 15
    """, [painter_name]).pl()
    
    if len(subjects) > 0:
        for row in subjects.iter_rows(named=True):
            source_tag = f"[{row['subject_source']}]" if row['subject_source'] else ""
            print(f"   • {row['subject_label'][:50]} {source_tag}: {row['occurrences']}x")
    else:
        print("   No subject data available for this painter.")
    
    # Collaborators (other painters on same works)
    print(f"\n🤝 COLLABORATORS")
    print("-" * 70)
    
    collaborators = con.execute("""
        SELECT 
            pp2.person_name as collaborator,
            pp2.role,
            COUNT(DISTINCT pp1.nfdi_uri) as shared_works
        FROM painting_persons pp1
        JOIN painting_persons pp2 ON pp1.nfdi_uri = pp2.nfdi_uri
        WHERE pp1.person_name = ? 
          AND pp2.person_name != ?
          AND pp1.role = 'PAINTER'
        GROUP BY pp2.person_name, pp2.role
        ORDER BY shared_works DESC
        LIMIT 10
    """, [painter_name, painter_name]).pl()
    
    if len(collaborators) > 0:
        for row in collaborators.iter_rows(named=True):
            print(f"   • {row['collaborator']} ({row['role']}): {row['shared_works']} shared work(s)")
    else:
        print("   No documented collaborators.")
    
    print("\n" + "=" * 70)
    
    return works  # Return works DataFrame for visualization

print("✅ Painter CV function ready.")
print(f"   Usage: generate_painter_cv('Painter Name')")
print(f"   Available painters: {len(PAINTER_LIST)}")
# Out:
# ✅ Painter CV function ready.
#    Usage: generate_painter_cv('Painter Name')
#    Available painters: 332

# %%
# =============================================================================
# Select a Painter and Generate CV
# =============================================================================

# Change this to explore different painters!
SELECTED_PAINTER = PAINTER_LIST[0] if PAINTER_LIST else None

if SELECTED_PAINTER:
    works_df = generate_painter_cv(SELECTED_PAINTER)
else:
    print("No painters found in database.")
# Out:
# ======================================================================
# 🎨 PAINTER CV: Harms, Johann Oswald
# ======================================================================
#
# 📋 OVERVIEW
#    Type: ACTOR_PERSON
#    Total documented works: 119
#    Buildings worked in: 7
#    German states covered: 4
#    Active period: 1569 - 1780 (211 years)
#
# 📅 WORKS TIMELINE
# ----------------------------------------------------------------------
#     1. [       ~1569] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#     2. [        1682] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das Audienzzimmer der Herzogin (116)
#                           State: Thüringen
#     3. [        1682] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das Audienzzimmer der Herzogin (116)
#                           State: Thüringen
#     4. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#     5. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#     6. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#     7. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#     8. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           State: Sachsen-Anhalt
#     9. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    10. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    11. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    12. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    13. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    14. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    15. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    16. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           State: Sachsen-Anhalt
#    17. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    18. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    19. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    20. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    21. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    22. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    23. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    24. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    25. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    26. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    27. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    28. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    29. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    30. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    31. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    32. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    33. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    34. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    35. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    36. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    37. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    38. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    39. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    40. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           State: Sachsen-Anhalt
#    41. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    42. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    43. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    44. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    45. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    46. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    47. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    48. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    49. [        1682] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    50. [        1683] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das Kabinett des Herzogs (113)
#                           State: Thüringen
#    51. [   1683-1702] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das gemeinsame herzogliche Schlafzimmer (114)
#                           State: Thüringen
#    52. [        1683] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das Kabinett der Herzogin (115)
#                           State: Thüringen
#    53. [        1683] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das Kabinett der Herzogin (115)
#                           State: Thüringen
#    54. [        1683] Weißenfels, Schloss Neu-Augustusburg
#                           State: Sachsen-Anhalt
#    55. [        1683] Weißenfels, Schloss Neu-Augustusburg
#                           State: Sachsen-Anhalt
#    56. [        1683] Weißenfels, Schloss Neu-Augustusburg
#                           State: Sachsen-Anhalt
#    57. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    58. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    59. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    60. [        1684] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das Audienzzimmer des Herzogs (112)
#                           State: Thüringen
#    61. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    62. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    63. [        1684] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das Audienzzimmer des Herzogs (112)
#                           State: Thüringen
#    64. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    65. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    66. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    67. [   1684-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    68. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    69. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    70. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    71. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    72. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    73. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    74. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    75. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    76. [        1685] Eisenberg, Residenzschloss Christiansbur
#                           Room: Das Vorzimmer des Herzogs / Tafelgemach (106)
#                           State: Thüringen
#    77. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    78. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    79. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    80. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    81. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    82. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    83. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    84. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    85. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    86. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    87. [   1685-1686] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    88. [        1685] Weißenfels, Schloss Neu-Augustusburg
#                           State: Sachsen-Anhalt
#    89. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Gemach des Landgrafen
#                           State: Hessen
#    90. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Vorgemach der Landgräfin
#                           State: Hessen
#    91. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Vorgemach der Landgräfin
#                           State: Hessen
#    92. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Gemach der Landgräfin
#                           State: Hessen
#    93. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Vorgemach der Landgräfin
#                           State: Hessen
#    94. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Vorgemach der Landgräfin
#                           State: Hessen
#    95. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Vorgemach der Landgräfin
#                           State: Hessen
#    96. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Vorgemach der Landgräfin
#                           State: Hessen
#    97. [        1688] Kassel, ehem. Residenzschloss
#                           Room: Gemach des Landgrafen
#                           State: Hessen
#    98. [        1695] Hamburg, Landhaus Schel
#                           Room: Verlorener Raum des Landhauses
#                           State: Hamburg
#    99. [  ~1700-1730] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    100. [  ~1700-1730] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    101. [  ~1700-1730] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    102. [  ~1700-1730] Eisenberg, Residenzschloss Christiansbur
#                           Room: Die Schlosskapelle St. Trinitatis
#                           State: Thüringen
#    103. [        1701] Kassel, ehem. Kunsthaus
#                           Room: Der ehemalige Anatomiesaal
#                           State: Hessen
#    104. [        1701] Kassel, ehem. Kunsthaus
#                           Room: Der ehemalige Anatomiesaal
#                           State: Hessen
#    105. [        1701] Kassel, ehem. Kunsthaus
#                           Room: Der ehemalige Anatomiesaal
#                           State: Hessen
#    106. [        1701] Kassel, ehem. Kunsthaus
#                           Room: Der ehemalige Anatomiesaal
#                           State: Hessen
#    107. [        1701] Kassel, ehem. Kunsthaus
#                           Room: Der ehemalige Anatomiesaal
#                           State: Hessen
#    108. [        1701] Kassel, ehem. Kunsthaus
#                           Room: Der ehemalige Anatomiesaal
#                           State: Hessen
#    109. [        1701] Kassel, ehem. Kunsthaus
#                           Room: Der ehemalige Anatomiesaal
#                           State: Hessen
#    110. [   1701-1702] Kassel, ehem. Kunsthaus
#                           Room: "auff der Rehnbahn / im Kunsthause in Caßel "
#                           State: Hessen
#    111. [        1701] Kassel, ehem. Kunsthaus
#                           Room: Der ehemalige Anatomiesaal
#                           State: Hessen
#    112. [        1702] Kassel, ehem. Kunsthaus
#                           Room: Optisches Gemach
#                           State: Hessen
#    113. [        1703] Wabern, Jagdschloss (Karlshof)
#                           Room: Der Gartensaal
#                           State: Hessen
#    114. [        1704] Kassel, ehem. Kunsthaus
#                           Room: Das ehem. Architektur-Militärgemach
#                           State: Hessen
#    115. [   1706-1707] Kassel, Orangerie
#                           Room: Die ehemaligen Galerien
#                           State: Hessen
#    116. [  ~1710-1720] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    117. [   1710-1714] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    118. [   1760-1780] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#    119. [       ~1770] Weißenfels, Schloss Neu-Augustusburg
#                           Room: Die Schlosskirche
#                           State: Sachsen-Anhalt
#
# 🗺️ GEOGRAPHIC FOOTPRINT
# ----------------------------------------------------------------------
#    • Sachsen-Anhalt: 55 work(s) in 1 building(s)
#    • Thüringen: 41 work(s) in 1 building(s)
#    • Hessen: 22 work(s) in 4 building(s)
#    • Hamburg: 1 work(s) in 1 building(s)
#
# 🏛️ BUILDING TYPES
# ----------------------------------------------------------------------
#
# 📚 ICONOGRAPHIC THEMES
# ----------------------------------------------------------------------
#    • ceiling paintings [GETTY_AAT]: 119x
#    • cupids: 'amores', 'amoretti', 'putti' [ICONCLASS]: 23x
#    • angels singing, making music [ICONCLASS]: 11x
#    • medicine, medical science [ICONCLASS]: 8x
#    • (decorated) ceiling [ICONCLASS]: 6x
#    • (human) skeleton [ICONCLASS]: 6x
#    • medical instruments [ICONCLASS]: 5x
#    • interior ~ architectural design or model [ICONCLASS]: 5x
#    • angels [ICONCLASS]: 5x
#    • architectural settings in paintings, sculptures, e [ICONCLASS]: 4x
#    • symbols and personifications of Death [ICONCLASS]: 4x
#    • [48C14%28%2B342%29] [ICONCLASS]: 4x
#    • angel(s) with book(-scroll) or banderole [ICONCLASS]: 4x
#    • art (+ mural painting) [ICONCLASS]: 4x
#    • banderole [ICONCLASS]: 4x
#
# 🤝 COLLABORATORS
# ----------------------------------------------------------------------
#    • Johann Adolf I., Herzog von Sachsen-Weißenfels (COMMISSIONER): 54 shared work(s)
#    • Christian, Sachsen-Eisenberg, Herzog (COMMISSIONER): 41 shared work(s)
#    • Karl, Hessen-Kassel, Landgraf (COMMISSIONER): 22 shared work(s)
#    • Schildbach, Hans Georg (PAINTER): 1 shared work(s)
#    • Caroveri, Giovanni (PLASTERER): 1 shared work(s)
#    • Quadro, Bartholomeo (PLASTERER): 1 shared work(s)
#    • Johann Adolf I., Herzog von Sachsen-Weißenfels (ARCHITECT): 1 shared work(s)
#    • Marie Amelie, Hessen-Kassel, Landgräfin (COMMISSIONER): 1 shared work(s)
#
# ======================================================================

# %%
# =============================================================================
# Painter Career Timeline Visualization
# =============================================================================

def visualize_painter_timeline(painter_name: str):
    """Create a timeline visualization of a painter's career."""
    
    timeline_data = con.execute("""
        SELECT 
            p.label,
            CAST(p.year_start AS INTEGER) as year_start,
            CAST(p.year_end AS INTEGER) as year_end,
            p.building_name,
            p.building_function,
            p.location_state
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        WHERE pp.role = 'PAINTER' 
          AND pp.person_name = ?
          AND p.year_start IS NOT NULL
        ORDER BY p.year_start
    """, [painter_name]).pl()
    
    if len(timeline_data) == 0:
        print(f"No dated works found for {painter_name}")
        return
    
    # Convert to pandas for Altair
    df = timeline_data.to_pandas()
    df['year_end'] = df['year_end'].fillna(df['year_start'])
    df['duration'] = df['year_end'] - df['year_start'] + 1
    df['building_short'] = df['building_name'].str[:30] + '...'
    
    # Gantt-style timeline
    chart = alt.Chart(df).mark_bar().encode(
        x=alt.X('year_start:Q', title='Year', scale=alt.Scale(zero=False)),
        x2='year_end:Q',
        y=alt.Y('building_short:N', sort=alt.EncodingSortField('year_start'), title='Building'),
        color=alt.Color('building_function:N', title='Building Type'),
        tooltip=['label', 'building_name', 'building_function', 'location_state', 'year_start', 'year_end']
    ).properties(
        title=f'Career Timeline: {painter_name}',
        width=700,
        height=max(100, len(df) * 5)
    )
    
    ipython_display(chart)
    return chart

# Visualize selected painter
if SELECTED_PAINTER:
    print(f"\n📊 CAREER TIMELINE: {SELECTED_PAINTER}")
    visualize_painter_timeline(SELECTED_PAINTER)
# Out:
# 📊 CAREER TIMELINE: Harms, Johann Oswald
# alt.Chart(...)

# %%
# =============================================================================
# Painter Subject Preferences Visualization
# =============================================================================

def visualize_painter_subjects(painter_name: str):
    """Visualize the iconographic themes preferred by a painter."""
    
    subjects_data = con.execute("""
        SELECT 
            s.subject_label,
            s.subject_source,
            CAST(COUNT(*) AS INTEGER) as count
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        JOIN painting_subjects ps ON p.nfdi_uri = ps.nfdi_uri
        JOIN subjects s ON ps.subject_uri = s.subject_uri
        WHERE pp.role = 'PAINTER' AND pp.person_name = ?
          AND s.subject_label IS NOT NULL
        GROUP BY s.subject_label, s.subject_source
        ORDER BY count DESC
        LIMIT 15
    """, [painter_name]).pl()
    
    if len(subjects_data) == 0:
        print(f"No subject data found for {painter_name}")
        return
    
    df = subjects_data.to_pandas()
    df['subject_short'] = df['subject_label'].str[:40]
    
    chart = alt.Chart(df).mark_bar().encode(
        x=alt.X('count:Q', title='Number of Works'),
        y=alt.Y('subject_short:N', sort='-x', title='Subject/Theme'),
        color=alt.Color('subject_source:N', title='Source'),
        tooltip=['subject_label', 'subject_source', 'count']
    ).properties(
        title=f'Iconographic Themes: {painter_name}',
        width=500,
        height=max(100, len(df) * 25)
    )
    
    ipython_display(chart)
    return chart

# Visualize selected painter's subjects
if SELECTED_PAINTER:
    print(f"\n📚 ICONOGRAPHIC THEMES: {SELECTED_PAINTER}")
    visualize_painter_subjects(SELECTED_PAINTER)
# Out:
# 📚 ICONOGRAPHIC THEMES: Harms, Johann Oswald
# alt.Chart(...)

# %%
# =============================================================================
# Compare Multiple Painters
# =============================================================================

def compare_painters(painter_names: list):
    """Compare career statistics of multiple painters."""
    
    if not painter_names:
        print("Please provide a list of painter names to compare.")
        return
    
    placeholders = ', '.join(['?' for _ in painter_names])
    
    comparison = con.execute(f"""
        SELECT 
            pp.person_name,
            CAST(COUNT(DISTINCT pp.nfdi_uri) AS INTEGER) as works,
            CAST(COUNT(DISTINCT p.building_id) AS INTEGER) as buildings,
            CAST(COUNT(DISTINCT p.location_state) AS INTEGER) as states,
            MIN(p.year_start) as career_start,
            MAX(p.year_end) as career_end
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        WHERE pp.role = 'PAINTER' AND pp.person_name IN ({placeholders})
        GROUP BY pp.person_name
        ORDER BY works DESC
    """, painter_names).pl()
    
    print("\n🎨 PAINTER COMPARISON")
    print("=" * 70)
    print(comparison)
    
    # Visualization
    df = comparison.to_pandas()
    
    # Works comparison
    chart = alt.Chart(df).mark_bar().encode(
        x=alt.X('works:Q', title='Number of Works'),
        y=alt.Y('person_name:N', sort='-x', title='Painter'),
        color=alt.Color('states:Q', scale=alt.Scale(scheme='viridis'), title='States'),
        tooltip=['person_name', 'works', 'buildings', 'states', 'career_start', 'career_end']
    ).properties(
        title='Painter Comparison: Works & Geographic Reach',
        width=500,
        height=max(100, len(df) * 40)
    )
    
    ipython_display(chart)
    return comparison

# Compare top painters
if len(PAINTER_LIST) >= 2:
    top_painters = PAINTER_LIST[:min(5, len(PAINTER_LIST))]
    print(f"Comparing: {', '.join(top_painters)}")
    compare_painters(top_painters)
# Out:
# Comparing: Harms, Johann Oswald, Lammers, Seivert, Castelli, Carlo Ludovico, Asam, Cosmas Damian, Ritter, Johann Heinrich
#
# 🎨 PAINTER COMPARISON
# ======================================================================
# shape: (5, 6)
# ┌──────────────────────────┬───────┬───────────┬────────┬──────────────┬────────────┐
# │ person_name              ┆ works ┆ buildings ┆ states ┆ career_start ┆ career_end │
# │ ---                      ┆ ---   ┆ ---       ┆ ---    ┆ ---          ┆ ---        │
# │ str                      ┆ i32   ┆ i32       ┆ i32    ┆ i32          ┆ i32        │
# ╞══════════════════════════╪═══════╪═══════════╪════════╪══════════════╪════════════╡
# │ Harms, Johann Oswald     ┆ 119   ┆ 7         ┆ 4      ┆ 1569         ┆ 1780       │
# │ Lammers, Seivert         ┆ 82    ┆ 4         ┆ 1      ┆ 1670         ┆ 1750       │
# │ Castelli, Carlo Ludovico ┆ 70    ┆ 8         ┆ 3      ┆ 1683         ┆ 1770       │
# │ Asam, Cosmas Damian      ┆ 63    ┆ 7         ┆ 2      ┆ 1670         ┆ 1948       │
# │ Ritter, Johann Heinrich  ┆ 58    ┆ 6         ┆ 1      ┆ 1580         ┆ 1780       │
# └──────────────────────────┴───────┴───────────┴────────┴──────────────┴────────────┘
# alt.Chart(...)

# %%
# =============================================================================
# Painter Geographic Map Data
# =============================================================================

def get_painter_locations(painter_name: str):
    """Get all locations where a painter worked with coordinates."""
    
    locations = con.execute("""
        SELECT 
            p.label,
            p.building_name,
            p.lat,
            p.lon,
            p.location_state,
            p.year_start,
            p.imageUrl
        FROM painting_persons pp
        JOIN paintings p ON pp.nfdi_uri = p.nfdi_uri
        WHERE pp.role = 'PAINTER' AND pp.person_name = ?
          AND p.lat IS NOT NULL AND p.lon IS NOT NULL
        ORDER BY p.year_start
    """, [painter_name]).pl()
    
    print(f"\n🗺️ WORK LOCATIONS: {painter_name}")
    print("=" * 70)
    print(f"Found {len(locations)} works with coordinates\n")
    
    if len(locations) > 0:
        # Create a simple point map
        df = locations.to_pandas()
        
        chart = alt.Chart(df).mark_circle(size=100).encode(
            longitude='lon:Q',
            latitude='lat:Q',
            color=alt.Color('location_state:N', title='State'),
            tooltip=['building_name', 'label', 'location_state', 'year_start']
        ).properties(
            title=f'Work Locations: {painter_name}',
            width=600,
            height=400
        ).project('mercator')
        
        ipython_display(chart)
    
    return locations

# Show locations for selected painter
if SELECTED_PAINTER:
    locations_df = get_painter_locations(SELECTED_PAINTER)
# Out:
# 🗺️ WORK LOCATIONS: Harms, Johann Oswald
# ======================================================================
# Found 119 works with coordinates
# alt.Chart(...)

# %%
# =============================================================================
# Interactive Painter Explorer
# =============================================================================

# List all available painters for easy selection
print("🎨 AVAILABLE PAINTERS FOR ANALYSIS")
print("=" * 70)
print("Copy a painter name from below to explore their CV:\n")

for i, row in enumerate(painters_overview.iter_rows(named=True), 1):
    works = row['painting_count']
    buildings = row['building_count']
    career = f"{row['career_start']}-{row['career_end']}" if row['career_start'] else "undated"
    print(f"  {i:2}. {row['person_name']:<35} | {works:>2} works | {buildings:>2} buildings | {career}")

print("\n" + "=" * 70)
print("💡 To explore a specific painter, change SELECTED_PAINTER in cell 4")
print("   or call: generate_painter_cv('Painter Name')")
# Out:
# 🎨 AVAILABLE PAINTERS FOR ANALYSIS
# ======================================================================
# Copy a painter name from below to explore their CV:
#
#    1. Harms, Johann Oswald                | 119 works |  7 buildings | 1569-1780
#   128. Schildbach, Christian               |  4 works |  1 buildings | 1677-1701
#   129. Colombo, Giovanni Battista Innocenzo |  4 works |  3 buildings | 1745-1768
#   130. Zanetti, Domenico                   |  4 works |  2 buildings | 1695-1715
#   131. Roscher, Georg Michael              |  4 works |  3 buildings | 1747-1759
#   132. Zöllner, Rudolph Christian Albert   |  4 works |  1 buildings | 1763-1772
#   133. Abel, Hans                          |  4 works |  1 buildings | 1546-1553
#   134. Pedetti, Francesco                  |  4 works |  1 buildings | 1943-1948
#   135. Witte, Engelbert Ernst              |  4 works |  1 buildings | 1708-1713
#   136. Feuerlein, Johann Peter             |  4 works |  1 buildings | 1700-1705
#   137. Eckstein, Johann Georg              |  4 works |  1 buildings | 1790-1793
#   138. Roli, Giuseppe Maria                |  4 works |  1 buildings | 1703-1706
#   139. Meyer, Johann Nicolaus              |  4 works |  2 buildings | 1720-1722
#   140. Rottenhammer, Hans                  |  4 works |  1 buildings | 1605-1606
#   141. Hopfer, Georg Thomas                |  4 works |  1 buildings | 1680-1681
#   142. Bauer, Johann Hermann               |  4 works |  1 buildings | 1747-1748
#   143. Heybel, Jakob                       |  4 works |  1 buildings | 1669-1669
#   144. Hengge, Meinrad                     |  4 works |  1 buildings | 1767-1767
#   145. Kuhl, H.                            |  4 works |  1 buildings | 1597-1597
#   146. Carlone, Giovanni                   |  4 works |  1 buildings | 1692-1692
#   147. Demmel, Augustin Joseph             |  4 works |  1 buildings | 1780-1780
#   148. Koppers, Johann Anton               |  4 works |  2 buildings | 1740-1740
#   149. Pellegrini, Giovanni Antonio        |  3 works |  3 buildings | 1713-1972
#   150. Krahe, Lambert                      |  3 works |  2 buildings | 1758-1943
#   151. Baeller, Niels Pedersen             |  3 works |  1 buildings | 1720-1784
#   152. Bigari, Vittorio Maria              |  3 works |  1 buildings | 1704-1741
#   153. Harper, Johann                      |  3 works |  2 buildings | 1725-1750
#   154. Schöpf, Johann Adam                 |  3 works |  2 buildings | 1745-1760
#   155. Pfleger, Franz                      |  3 works |  1 buildings | 1716-1725
#   156. Vogel, Johann Christian             |  3 works |  1 buildings | 1740-1745
#   157. Deyssinger, Johann Leopold          |  3 works |  2 buildings | 1743-1747
#   158. Bock, Friedrich Wilhelm             |  3 works |  2 buildings | 1770-1773
#   159. Baron, Karl Christian Wilhelm       |  3 works |  2 buildings | 1770-1773
#   160. Fechhelm, Johann Friedrich          |  3 works |  1 buildings | 1781-1784
#   161. Huber, Johann Rudolf                |  3 works |  1 buildings | 1698-1700
#   162. Beck, Jakob Samuel                  |  3 works |  1 buildings | 1744-1746
#   163. Remele, Johann Adam                 |  3 works |  1 buildings | 1728-1729
#   164. Etschmann, Paul                     |  3 works |  1 buildings | 1691-1692
#   165. Dubuisson, Augustin                 |  3 works |  1 buildings | 1747-1747
#   166. Vercrucien, Anton                   |  3 works |  1 buildings | 1710-1710
#   167. Meil, Johann Ludwig                 |  3 works |  1 buildings | 1771-1771
#   168. Burnat, Peter Ludwig                |  3 works |  1 buildings | 1795-1795
#   169. Morath, Johann Anton                |  3 works |  1 buildings | 1750-1750
#   297. Pfunner, Johann                     |  1 works |  1 buildings | 1761-1761
#   298. Vos, Marten de, der Ältere          |  1 works |  1 buildings | 1569-1569
#   299. Pittoni, Giovanni Battista          |  1 works |  1 buildings | 1734-1734
#   300. Leitkrath, Joseph                   |  1 works |  1 buildings | 1786-1786
#   301. Christ, Josef                       |  1 works |  1 buildings | 1770-1770
#   302. Richter, Christian (I.)             |  1 works |  1 buildings | 1663-1663
#   303. Beeldemaker, Adriaen Cornelisz      |  1 works |  1 buildings | 1670-1670
#   304. Müller, Johann Heinrich             |  1 works |  1 buildings | 1732-1732
#   305. Theil, Benedict                     |  1 works |  1 buildings | 1753-1753
#   306. Weingart, Peter                     |  1 works |  1 buildings | 1738-1738
#   307. Zanchi, Antonio                     |  1 works |  1 buildings | 1674-1674
#   308. Maulbertsch, Franz Anton            |  1 works |  1 buildings | 1770-1770
#   309. Vos, Marten de, Werkstatt           |  1 works |  1 buildings | 1572-1572
#   310. Franz, Johann Michael               |  1 works |  1 buildings | 1786-1786
#   311. Waxschlunger, Johann Paul           |  1 works |  1 buildings | 1720-1720
#   312. Ehrenfried, Karl Gustav             |  1 works |  1 buildings | 1751-1751
#   313. Dichtel, Franz Joseph               |  1 works |  1 buildings | 1748-1748
#   314. Oettingen-Spielberg, Ludovika Rosalie von |  1 works |  1 buildings | 1683-1683
#   315. Guglielmi, Gregorio                 |  1 works |  1 buildings | 1764-1764
#   316. Rugendas, Georg Philipp, der Jüngere |  1 works |  1 buildings | 1722-1722
#   317. Fehling, Heinrich Christoph         |  1 works |  1 buildings | 1690-1690
#   318. Giorgioli, Francesco Antonio        |  1 works |  1 buildings | 1720-1720
#   319. Am Ende, Johann Heinrich            |  1 works |  1 buildings | 1687-1687
#   320. Baumgartner, Johann Wolfgang        |  1 works |  1 buildings | 1760-1760
#   321. Schnaible, Johann Bernhard          |  1 works |  1 buildings | 1769-1769
#   322. Palko, Franz Karl                   |  1 works |  1 buildings | 1754-1754
#   323. Joh.....g                           |  1 works |  1 buildings | 1656-1656
#   324. Gericke, Samuel Theodor             |  1 works |  1 buildings | 1687-1687
#   325. Schmeller, Johann Joseph            |  1 works |  1 buildings | 1820-1820
#   326. Triva, Antonio Domenico             |  1 works |  1 buildings | 1673-1673
#   327. Grätsch, J.                         |  1 works |  1 buildings | undated
#   328. Onghers, Jan                        |  1 works |  1 buildings | undated
#   329. Martin-Amorbach, Oskar              |  1 works |  1 buildings | undated
#   330. Scheitler, Anton                    |  1 works |  1 buildings | undated
#   331. Probst, Johann Michael              |  1 works |  1 buildings | 1781-None
#   332. Reiser, Ambros                      |  1 works |  1 buildings | undated
#
# ======================================================================
# 💡 To explore a specific painter, change SELECTED_PAINTER in cell 4
#    or call: generate_painter_cv('Painter Name')

# %%
# =============================================================================
# Explore Another Painter (Change name here!)
# =============================================================================

# 👇 CHANGE THIS NAME to explore a different painter
EXPLORE_PAINTER = PAINTER_LIST[1] if len(PAINTER_LIST) > 1 else PAINTER_LIST[0] if PAINTER_LIST else None

if EXPLORE_PAINTER:
    works = generate_painter_cv(EXPLORE_PAINTER)
    print("\n")
    visualize_painter_timeline(EXPLORE_PAINTER)
    visualize_painter_subjects(EXPLORE_PAINTER)
# Out:
# ======================================================================
# 🎨 PAINTER CV: Lammers, Seivert
# ======================================================================
#
# 📋 OVERVIEW
#    Type: ACTOR_PERSON
#    Total documented works: 82
#    Buildings worked in: 4
#    German states covered: 1
#    Active period: 1670 - 1750 (80 years)
#
# 📅 WORKS TIMELINE
# ----------------------------------------------------------------------
#     1. [   1670-1680] Rudolstadt, Residenzschloss Heidecksburg
#                           Room: Der Nebenraum zur so genannten Biedermeiergarderob
#                           State: Thüringen
#     2. [   1670-1680] Rudolstadt, Residenzschloss Heidecksburg
#                           Room: Der Nebenraum zur so genannten Biedermeiergarderob
#                           State: Thüringen
#     3. [   1670-1680] Rudolstadt, Residenzschloss Heidecksburg
#                           Room: Der Nebenraum zur so genannten Biedermeiergarderob
#                           State: Thüringen
#     4. [        1688] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Das so genannte Fürstenzimmer
#                           State: Thüringen
#     5. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#     6. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#     7. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#     8. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#     9. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    10. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    11. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    12. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    13. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    14. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    15. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    16. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    17. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    18. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    19. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    20. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    21. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    22. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    23. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    24. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    25. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    26. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    27. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    28. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    29. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    30. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    31. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    32. [   1690-1703] Sondershausen, Residenzschloss
#                           Room: Der Hauptsaal "Riesensaal" im zweiten Obergeschoss
#                           State: Thüringen
#    33. [   1695-1696] Gotha, Residenzschloss Friedenstein
#                           Room: Das Porzellankabinett
#                           State: Thüringen
#    34. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    35. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    36. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    37. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    38. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    39. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    40. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    41. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    42. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    43. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    44. [   1696-1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    45. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    46. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    47. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    48. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    49. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    50. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Das Betkabinett mit Altarbereich
#                           State: Thüringen
#    51. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    52. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    53. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    54. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    55. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    56. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    57. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    58. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    59. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Das Betkabinett mit Altarbereich
#                           State: Thüringen
#    60. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    61. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    62. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    63. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    64. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    65. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    66. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    67. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    68. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    69. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    70. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    71. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    72. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Die Schlosskirche
#                           State: Thüringen
#    73. [        1697] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    74. [        1698] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Der so genannte Schlachtensaal
#                           State: Thüringen
#    75. [        1698] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Der so genannte Schlachtensaal
#                           State: Thüringen
#    76. [        1698] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Der so genannte Schlachtensaal
#                           State: Thüringen
#    77. [        1698] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Der so genannte Schlachtensaal
#                           State: Thüringen
#    78. [        1698] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Das so genannte Davidzimmer
#                           State: Thüringen
#    79. [        1698] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Der so genannte Schlachtensaal
#                           State: Thüringen
#    80. [        1698] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Das so genannte Davidzimmer
#                           State: Thüringen
#    81. [   1730-1750] Gotha, Residenzschloss Friedenstein
#                           Room: Der Herrschaftsstand
#                           State: Thüringen
#    82. [   (undated)] Leutenberg, ehem. Schloss "Friedensburg"
#                           Room: Der so genannte Schlachtensaal
#                           State: Thüringen
#
# 🗺️ GEOGRAPHIC FOOTPRINT
# ----------------------------------------------------------------------
#    • Thüringen: 82 work(s) in 4 building(s)
#
# 🏛️ BUILDING TYPES
# ----------------------------------------------------------------------
#
# 📚 ICONOGRAPHIC THEMES
# ----------------------------------------------------------------------
#    • ceiling paintings [GETTY_AAT]: 82x
#    • [44B112%28ROME%29] [ICONCLASS]: 8x
#    • (story of) Cupid, Amor (Eros) [ICONCLASS]: 3x
#    • battle [ICONCLASS]: 3x
#    • Giving [ICONCLASS]: 3x
#    • angels singing, making music [ICONCLASS]: 3x
#    • peace and prosperity, 'Pax et Abundantia' [ICONCLASS]: 2x
#    • Welfare, Prosperity; 'Felicità publica', 'Prosperi [ICONCLASS]: 2x
#    • (story of) Jupiter (Zeus) [ICONCLASS]: 2x
#    • disarmament [ICONCLASS]: 2x
#    • suspension of hostilities (truce) [ICONCLASS]: 2x
#    • hacking and thrusting weapons: sword [ICONCLASS]: 2x
#    • [83%28OVID%2C%20Metamorphoses%20VIII%3A329-375%29] [ICONCLASS]: 2x
#    • Scylla offers the lock to Minos, who rejects her o [ICONCLASS]: 1x
#    • Hercules shoots Nessus, the centaur, who attempts  [ICONCLASS]: 1x
#
# 🤝 COLLABORATORS
# ----------------------------------------------------------------------
#    • Friedrich II., Sachsen-Gotha-Altenburg, Herzog (COMMISSIONER): 42 shared work(s)
#    • Christian Wilhelm, Schwarzburg-Sondershausen, Graf (COMMISSIONER): 28 shared work(s)
#    • Richter, Johann Wilhelm (PAINTER): 28 shared work(s)
#    • Wentzing, Heinrich Richard (PAINTER): 28 shared work(s)
#    • Albert Anton, Schwarzburg-Rudolstadt, Graf (COMMISSIONER): 12 shared work(s)
#    • Tempesta, Antonio (TEMPLATE_PROVIDER): 10 shared work(s)
#    • Sadeler, Aegidius II. (TEMPLATE_PROVIDER): 6 shared work(s)
#    • Le Pautre, Jean (TEMPLATE_PROVIDER): 3 shared work(s)
#    • Ritter, Johann Heinrich (PAINTER): 1 shared work(s)
#    • Sacchi, Andrea (TEMPLATE_PROVIDER): 1 shared work(s)
#
# ======================================================================
# alt.Chart(...)
# alt.Chart(...)

# %%
# =============================================================================
# Close Connection (optional)
# =============================================================================

# Uncomment to close the connection when done
# con.close()
# print("✅ Database connection closed")

print("💡 Tip: This notebook connects in read-only mode.")
print("   The database can be used by multiple notebooks simultaneously.")
# Out:
# 💡 Tip: This notebook connects in read-only mode.
#    The database can be used by multiple notebooks simultaneously.
